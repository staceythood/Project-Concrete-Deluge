# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# REFERENCE LINK FOR COLUMN DEFINITION
# https://www.fema.gov/openfema-dataset-housing-assistance-data-owners-v1

# FEMA Data | Alex Damage > 5000 | 68 rows | Some Houston Outliers
url = "https://www.fema.gov/api/open/v1/HousingAssistanceOwners?$filter=state%20eq%20%27TX%27%20and%20disasterNumber%20eq%20%271931%27%20and%20totalDamage%20gt%20%275000%27"

# Request articles
articles = requests.get(url).json()

print("FEMA DataSet : Housing Assistance Owners | Alex Damage > 5000")

data_df = pd.DataFrame(articles["HousingAssistanceOwners"])
data_df
# Out:
# FEMA DataSet : Housing Assistance Owners | Alex Damage > 5000
#     approvedBetween10001And25000  approvedBetween1And10000  \
# 0                              1                         2
# 1                              0                        77
# 2                              1                         3
# 3                              0                         5
# 4                              0                         7
# 5                              7                       132
# 6                              0                         2
# 7                              1                        14
# 8                              0                        55
# 9                              5                       170
# 10                             1                        29
# 11                             0                         6
# 12                             2                        95
# 13                             4                        53
# ...

# %%
export_csv = data_df.to_csv ("HousingAssistanceOwners_1931_alex.csv", encoding='utf-8', index=False, header=True)
