# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress

# %%
build_permits = pd.read_csv("../CensusBuildingPermitsCum2000_2018.csv")

build_permits.head()
# Out:
#    Year   Units   Value (000)  Value (Billions)  Cumulative
# 0  2000    35900   4,207,090               4.21        4.21
# 1  2001    37569   4,440,651               4.44        8.65
# 2  2002    47037   5,146,453               5.15       13.79
# 3  2003    56571   5,939,092               5.94       19.73
# 4  2004    56036   6,499,425               6.50       26.23

# %%
years = build_permits.iloc[:,0]
values = build_permits.iloc[:,4]
units = build_permits.iloc[:,1]

plt.plot(years,values,color="green")

plt.xlim(2000, 2018)

plt.title('Metro Houston Residential Building Permits 2000-2018')
plt.xlabel("Years")
plt.ylabel("Cumulative Value of Permits in Billions")
# Out:
# Text(0, 0.5, 'Cumulative Value of Permits in Billions')

# %%
plt.plot(years,units,color="blue")

plt.xlim(2000, 2018)

plt.title('Metro Houston Residential Building Permits 2000-2018')
plt.xlabel("Years")
plt.ylabel("Number of Permits")
# Out:
# Text(0, 0.5, 'Number of Permits')

# %%
fig, ax = plt.subplots()

(slope, intercept, _, _, _) = linregress(years, values)
fit = slope * years + intercept
ax.plot(years, fit,'r--')
ax.bar(years,values)

plt.xlim(2000, 2018)

plt.title('Metro Houston Residential Building Permits 2000-2018')
plt.xlabel("Years")
plt.ylabel("Value of Permits in Billions")
# Out:
# Text(0, 0.5, 'Value of Permits in Billions')

# %%
avecompaction = pd.read_csv("../Toalave_compbyyear.csv")

avecompaction
# Out:
#     Year  Total Ave
# 0   2000  -1.294777
# 1   2001  -1.304949
# 2   2002  -1.313009
# 3   2003  -1.319282
# 4   2004  -1.311744
# 5   2005  -1.311581
# 6   2006  -1.330068
# 7   2007  -1.318957
# 8   2008  -1.322852
# 9   2009  -1.347239
# 10  2010  -1.351795
# 11  2011  -1.399333
# 12  2012  -1.419241
# 13  2013  -1.435324
# 14  2014  -1.441465
# 15  2015  -1.418508
# 16  2016  -1.424089
# 17  2017  -1.437546
# 18  2018  -1.444046

# %%
subsidence = avecompaction.iloc[:,1]

# fig, ax = plt.subplots()

plt.figure(figsize=(15, 15))

#Plot building permit values by year from https://www.census.gov/construction/bps/ for the Metropolitan region of Houston 26420
# and significant flooding events per Harris County Flood Control District (HCFCD)https://www.hcfcd.org/media/2381/historytimeline-24x36-1.pdf

plt.subplot(2, 1, 1)
plt.plot(years, values, 'r')
plt.axvline(x=2017.5,linestyle='--', color='red',label='Harvey')
plt.axvline(x=2016.3,linestyle='--', color='purple',label='2016 Memorial Day Flood')
plt.axvline(x=2016.5,linestyle='--', color='orange',label='2016 Tax Day Flood')
plt.axvline(x=2015.5,linestyle='--', color='blue',label='2015 Memorial Day Flood')
plt.axvline(x=2009.3,linestyle='--', color='yellow',label='2009 April Flood')
plt.axvline(x=2008.7,linestyle='--', color='darkblue',label='Ike')
plt.axvline(x=2006.5,linestyle='--', color='green',label='2006 June Flood')
plt.axvline(x=2001.5,linestyle='--', color='cyan',label='Allison')

plt.legend(loc='best', fontsize=12, bbox_to_anchor=(1, .8))
plt.title('Metro Houston Cumulative Building Permits 2000-2018',fontsize=14)
plt.xlabel("Years",fontsize=12)
plt.ylabel("Value of Permits in Billions of Dollars",fontsize=12)
plt.xlim(2000, 2018)

#Plot compaction/subsidence by year obtained form USGS https://www.sciencebase.gov/catalog/item/5cd30a76e4b09b8c0b7a5cb3
#and significant flooding events per Harris County Flood Control District (HCFCD) https://www.hcfcd.org/media/2381/historytimeline-24x36-1.pdf
plt.subplot(2, 1, 2)
plt.plot(years, subsidence, 'g')
plt.axvline(x=2017.5,linestyle='--', color='red',label='Harvey')
plt.axvline(x=2016.3,linestyle='--', color='purple',label='2016 Memorial Day Flood')
plt.axvline(x=2016.5,linestyle='--', color='orange',label='2016 Tax Day Flood')
plt.axvline(x=2015.5,linestyle='--', color='blue',label='2015 Memorial Day Flood')
plt.axvline(x=2009.3,linestyle='--', color='yellow',label='2009 April Flood')
plt.axvline(x=2008.7,linestyle='--', color='darkblue',label='Ike')
plt.axvline(x=2006.5,linestyle='--', color='green',label='2006 June Flood')
plt.axvline(x=2001.5,linestyle='--', color='cyan',label='Allison')
plt.legend(loc='best', fontsize=12, bbox_to_anchor=(1, .8))

plt.title('Metro Houston Average Subsidence/Compaction 2000-2018',fontsize=14)
plt.ylabel('Average Subsidence (feet)',fontsize=12)
plt.xlabel("Years",fontsize=12)
plt.xlim(2000, 2018)
plt.tight_layout()
plt.savefig("../permitsvscompaction.png")
plt.show()

# %%
fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(years, values, color = 'green')
ax2.plot(years, subsidence, 'b-')

ax1.set_xlabel('Years')
ax1.set_ylabel('Cumulative $ Value of Building Permits', color='g')
ax2.set_ylabel('Average Subsidence (feet)', color='b')

plt.xlim(2000, 2018)

plt.title('Metro Houston Building vs Subsidence 2000-2018')
# Out:
# Text(0.5, 1.0, 'Metro Houston Building vs Subsidence 2000-2018')

# %%
rita = pd.read_csv("../Brian/HAO_1606_rita.csv")
rita.head()
# Out:
#    approvedBetween10001And25000  approvedBetween1And10000  \
# 0                             1                       137
# 1                             0                         3
# 2                             1                        50
# 3                             0                        23
# 4                             3                       665
#
#    approvedBetween25001AndMax  approvedForFemaAssistance  \
# 0                           0                        138
# 1                           0                          3
# 2                           0                         51
# 3                           0                         23
# 4                           0                        668
#
#    averageFemaInspectedDamage      city             county  disasterNumber  \
# 0                         359     ALVIN  Brazoria (County)            1606
# 1                        1971  HANKAMER  Chambers (County)            1606
# 2                         863  BRAZORIA  Brazoria (County)            1606
# 3                         320    MANVEL  Brazoria (County)            1606
# 4                        1013    LUFKIN  Angelina (County)            1606
#
#    femaInspectedDamageBetween10001And20000  \
# 0                                        2
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        3
#
#    femaInspectedDamageBetween1And10000  ...  otherNeedsAmount  rentalAmount  \
# 0                                  229  ...             25546        172485
# 1                                    3  ...               807          2000
# 2                                   59  ...              9478         69717
# 3                                   37  ...              3971         32000
# 4                                  873  ...            289449        479157
#
#   repairReplaceAmount state totalApprovedIhpAmount  totalDamage  \
# 0               57344    TX                 255375       180498
# 1                5106    TX                   7913         5913
# 2               10951    TX                  90147       131191
# 3                2205    TX                  38177        26583
# 4              268220    TX                1036825      1317325
#
#    totalInspected  totalMaxGrants  validRegistrations zipCode
# 0             503               0                   1   77511
# 1               3               0                   3   77514
# 2             152               0                 357   77422
# 3              83               0                 164   77578
# 4            1301               0                   2   75904
#
# [5 rows x 26 columns]

# %%
rita_total = rita['totalDamage'].sum()
rita_total
# Out:
# 329743016

# %%
dolly = pd.read_csv("../Brian/HAO_1780_dolly.csv")
dolly.head()
# Out:
#    approvedBetween10001And25000  approvedBetween1And10000  \
# 0                             2                       192
# 1                             1                         9
# 2                             1                       106
# 3                             1                       139
# 4                            19                       525
#
#    approvedBetween25001AndMax  approvedForFemaAssistance  \
# 0                           0                        194
# 1                           0                         10
# 2                           0                        107
# 3                           0                        140
# 4                           3                        547
#
#    averageFemaInspectedDamage         city            county  disasterNumber  \
# 0                         823  BROWNSVILLE  Cameron (County)            1780
# 1                        1823      BAYVIEW  Cameron (County)            1780
# 2                         560  BROWNSVILLE  Cameron (County)            1780
# 3                         664        PHARR  Hidalgo (County)            1780
# 4                        1453        DONNA  Hidalgo (County)            1780
#
#    femaInspectedDamageBetween10001And20000  \
# 0                                        2
# 1                                        1
# 2                                        1
# 3                                        0
# 4                                       13
#
#    femaInspectedDamageBetween1And10000  ...  otherNeedsAmount  rentalAmount  \
# 0                                  422  ...             29102         68537
# 1                                   24  ...              1280          3072
# 2                                  359  ...             16632         33336
# 3                                  390  ...             23550         59839
# 4                                  922  ...            185138        265829
#
#   repairReplaceAmount state totalApprovedIhpAmount  totalDamage  \
# 0              270323    TX                 367963       398396
# 1               35707    TX                  40059        51034
# 2              128924    TX                 178892       242939
# 3              186379    TX                 269768       309330
# 4              985017    TX                1435984      1477870
#
#    totalInspected  totalMaxGrants  validRegistrations zipCode
# 0             484               0                 620   78520
# 1              28               0                  32   78566
# 2             434               0                 598   78526
# 3             466               0                 545   78577
# 4            1017               2                   1   78537
#
# [5 rows x 26 columns]

# %%
dolly_total = dolly['totalDamage'].sum()
dolly_total
# Out:
# 35282111

# %%
ike = pd.read_csv("../Brian/HAO_1791_ike.csv")
ike_total = ike['totalDamage'].sum()
ike_total
# Out:
# 828040097

# %%
alex = pd.read_csv("../Brian/HAO_1931_alex.csv")
alex_total = alex['totalDamage'].sum()
alex_total
# Out:
# 9527836
