# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import gmaps

from config import gkey
gmaps.configure(api_key=gkey)

# url = "https://www.fema.gov/api/open/v1/IndividualAssistanceHousingRegistrantsLargeDisasters?$format=json"
url = "https://www.fema.gov/api/open/v1/IndividualAssistanceHousingRegistrantsLargeDisasters?$orderby=tx"

# Request articles
articles = requests.get(url).json()

df_ZipCode = pd.DataFrame(columns = ["ZipCode"])

index_counter = 0
inside_counter = 5
print("FEMA DataSet : IndividualAssistanceHousingRegistrantsLargeDisasters")


# 2019-07-24: Huy Code to pull in entire JSON API..
data_df = pd.DataFrame(articles["IndividualAssistanceHousingRegistrantsLargeDisasters"])
data_df
# Out:
# FEMA DataSet : IndividualAssistanceHousingRegistrantsLargeDisasters
#        censusBlockId censusYear     damagedCity damagedStateAbbreviation  \
# 0    482013129002017       2017         HOUSTON                       TX
# 1    484579502005051       2017       WOODVILLE                       TX
# 2    483550054092001       2017  CORPUS CHRISTI                       TX
# 3    482014334001003       2017         HOUSTON                       TX
# 4    482013321001024       2017         HOUSTON                       TX
# 5    482917002001042       2017       CLEVELAND                       TX
# 6    481990303001365       2017         KOUNTZE                       TX
# 7    483550022004005       2017  CORPUS CHRISTI                       TX
# 8    481576706011001       2017   MISSOURI CITY                       TX
# 9    483396904024005       2017        MAGNOLIA                       TX
# 10   482015503024007       2017         HOUSTON                       TX
# ...
