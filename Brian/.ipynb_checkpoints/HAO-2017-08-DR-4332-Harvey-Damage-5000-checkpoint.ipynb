# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# REFERENCE LINK FOR COLUMN DEFINITION
# https://www.fema.gov/openfema-dataset-housing-assistance-data-owners-v1

# FEMA Data | Harvey Damage > 5000 | 718 rows | Some Houston Outliers
url = "https://www.fema.gov/api/open/v1/HousingAssistanceOwners?$filter=state%20eq%20%27TX%27%20and%20disasterNumber%20eq%20%274332%27%20and%20totalDamage%20gt%20%275000%27"

# Request articles
articles = requests.get(url).json()

print("FEMA DataSet : Housing Assistance Owners | Harvey Damage > 5000")

data_df = pd.DataFrame(articles["HousingAssistanceOwners"])
data_df
# Out:
# FEMA DataSet : Housing Assistance Owners | Harvey Damage > 5000
#      approvedBetween10001And25000  approvedBetween1And10000  \
# 0                              21                        28
# 1                               0                         7
# 2                               1                         4
# 3                              89                       412
# 4                               0                         2
# 5                               1                         2
# 6                              53                       609
# 7                               1                         0
# 8                               1                         1
# 9                               1                         0
# 10                              0                         5
# 11                              3                         3
# 12                             64                       934
# 13                              1                        11
# ...

# %%
export_csv = data_df.to_csv ("HousingAssistanceOwners_4332_harvey.csv", encoding='utf-8', index=False, header=True)
