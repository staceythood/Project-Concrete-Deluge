# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# REFERENCE LINK FOR COLUMN DEFINITION
# https://www.fema.gov/openfema-dataset-housing-assistance-data-owners-v1

# FEMA Data | Rita Damage > 5000 | 387 rows | Some Houston Outliers
url = "https://www.fema.gov/api/open/v1/HousingAssistanceOwners?$filter=state%20eq%20%27TX%27%20and%20disasterNumber%20eq%20%271606%27%20and%20totalDamage%20gt%20%275000%27"

# Request articles
articles = requests.get(url).json()

print("FEMA DataSet : Housing Assistance Owners | Rita Damage > 5000")

data_df = pd.DataFrame(articles["HousingAssistanceOwners"])
data_df
# Out:
# FEMA DataSet : Housing Assistance Owners | Rita Damage > 5000
#      approvedBetween10001And25000  approvedBetween1And10000  \
# 0                               1                       137
# 1                               0                         3
# 2                               1                        50
# 3                               0                        23
# 4                               3                       665
# 5                               1                        43
# 6                               1                         0
# 7                               0                       145
# 8                               0                        60
# 9                               2                       253
# 10                              0                        12
# 11                              7                       517
# 12                              3                        73
# 13                              0                        45
# ...

# %%
export_csv = data_df.to_csv ("HousingAssistanceOwners_1606_rita.csv", encoding='utf-8', index=False, header=True)
