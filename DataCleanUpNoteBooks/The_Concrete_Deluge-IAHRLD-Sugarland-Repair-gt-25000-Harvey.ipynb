# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# REFERENCE LINK FOR COLUMN DEFINITION
# https://www.fema.gov/openfema-dataset-individual-assistance-housing-registrants-large-disasters-v1

# FEMA Data | KINGWOOD Repair Amount > 25000 | 422 rows
url = "https://www.fema.gov/api/open/v1/IndividualAssistanceHousingRegistrantsLargeDisasters?$filter=damagedStateAbbreviation%20eq%20%27TX%27%20and%20damagedCity%20eq%20%27SUGAR LAND%27%20and%20repairAmount%20gt%2025000"

# Request articles
articles = requests.get(url).json()

print("FEMA DataSet : Individual Assistance Housing Registrants Large Disasters | SUGARLAND | Repair Amount > 25000")

data_df = pd.DataFrame(articles["IndividualAssistanceHousingRegistrantsLargeDisasters"])
data_df
# Out:
# FEMA DataSet : Individual Assistance Housing Registrants Large Disasters | SUGARLAND | Repair Amount > 25000
#       censusBlockId censusYear damagedCity damagedStateAbbreviation  \
# 0   481576744003057       2017  SUGAR LAND                       TX
# 1   481576745011089       2017  SUGAR LAND                       TX
# 2   481576745011023       2017  SUGAR LAND                       TX
# 3   481576744003056       2017  SUGAR LAND                       TX
# 4   481576727012035       2017  SUGAR LAND                       TX
# 5   481576745011023       2017  SUGAR LAND                       TX
# 6   481576744003056       2017  SUGAR LAND                       TX
# 7   481576744003056       2017  SUGAR LAND                       TX
# 8   481576727013000       2017  SUGAR LAND                       TX
# 9   481576744003056       2017  SUGAR LAND                       TX
# 10  481576723024006       2017  SUGAR LAND                       TX
# 11  481576744003056       2017  SUGAR LAND                       TX
# 12  481576727022019       2017  SUGAR LAND                       TX
# 13  481576744003056       2017  SUGAR LAND                       TX
# 14  481576745011023       2017  SUGAR LAND                       TX
# 15  481576744003057       2017  SUGAR LAND                       TX
# 16  481576745011023       2017  SUGAR LAND                       TX
# 17  481576744003056       2017  SUGAR LAND                       TX
# 18  481576727013003       2017  SUGAR LAND                       TX
# 19  481576744003056       2017  SUGAR LAND                       TX
# 20  481576744003057       2017  SUGAR LAND                       TX
# 21  481576744003056       2017  SUGAR LAND                       TX
# 22  481576745011023       2017  SUGAR LAND                       TX
# 23  481576727013000       2017  SUGAR LAND                       TX
# 24  481576745011023       2017  SUGAR LAND                       TX
# 25  481576741004001       2017  SUGAR LAND                       TX
#
#    damagedZipCode  destroyed disasterNumber  floodDamage  floodInsurance  \
# 0           77479      False           4332         True           False
# 1           77479      False           4332         True           False
# 2           77479      False           4332         True           False
# 3           77479      False           4332         True           False
# 4           77479      False           4332         True           False
# 5           77479      False           4332         True           False
# 6           77479      False           4332         True           False
# 7           77479      False           4332         True           False
# 8           77498      False           4332         True           False
# 9           77479      False           4332         True           False
# 10          77498      False           4332         True           False
# 11          77479      False           4332         True           False
# 12          77498      False           4332         True           False
# 13          77479      False           4332         True           False
# 14          77479      False           4332         True           False
# 15          77479      False           4332         True           False
# 16          77479      False           4332         True           False
# 17          77479      False           4332         True           False
# 18          77498      False           4332         True           False
# 19          77479      False           4332         True           False
# 20          77479      False           4332         True           False
# 21          77479      False           4332         True           False
# 22          77479      False           4332         True           False
# 23          77498      False           4332         True           False
# 24          77479      False           4332         True           False
# 25          77479      False           4332         True           False
#
#     foundationDamage     ...     replacementAssistanceEligible  residenceType  \
# 0              False     ...                             False   House/Duplex
# 1              False     ...                             False   House/Duplex
# 2              False     ...                             False   House/Duplex
# 3              False     ...                             False   House/Duplex
# 4              False     ...                             False   House/Duplex
# 5              False     ...                             False   House/Duplex
# 6              False     ...                             False   House/Duplex
# 7              False     ...                             False   House/Duplex
# 8              False     ...                             False   House/Duplex
# 9              False     ...                             False   House/Duplex
# 10             False     ...                             False   House/Duplex
# 11             False     ...                             False   House/Duplex
# 12             False     ...                             False   House/Duplex
# 13             False     ...                             False   House/Duplex
# 14             False     ...                             False   House/Duplex
# 15             False     ...                             False   House/Duplex
# 16             False     ...                             False   House/Duplex
# 17             False     ...                             False   House/Duplex
# 18             False     ...                             False   House/Duplex
# 19             False     ...                             False   House/Duplex
# 20             False     ...                             False   House/Duplex
# 21             False     ...                             False   House/Duplex
# 22             False     ...                             False   House/Duplex
# 23             False     ...                             False   House/Duplex
# 24             False     ...                             False   House/Duplex
# 25             False     ...                             False   House/Duplex
#
#     roofDamage  roofDamageAmount     rpfvl sbaEligible  specialNeeds  \
# 0        False               NaN  25381.89       False         False
# 1        False               NaN  25417.03       False         False
# 2        False               NaN  24528.50        True         False
# 3        False               NaN  21083.36       False         False
# 4        False               NaN  25891.75        True         False
# 5        False               NaN  20022.72       False         False
# 6        False               NaN  25501.81        True         False
# 7        False               NaN  26078.65       False         False
# 8        False               NaN  26272.73       False         False
# 9        False               NaN  26324.02       False         False
# 10        True            111.15  14926.85        True         False
# 11       False               NaN  27162.59        True         False
# 12       False               NaN  27557.27       False         False
# 13       False               NaN  18181.36       False         False
# 14       False               NaN  27951.32       False         False
# 15       False               NaN  36798.23       False         False
# 16       False               NaN  28737.58        True         False
# 17       False               NaN  17266.69        True         False
# 18       False               NaN  29078.13       False         False
# 19       False               NaN  48155.43       False         False
# 20       False               NaN  21729.23       False         False
# 21       False               NaN  30791.74        True         False
# 22       False               NaN  32052.60        True         False
# 23       False               NaN  48681.34       False         False
# 24       False               NaN  31028.07        True         False
# 25       False               NaN   5676.07       False         False
#
#    tsaCheckedIn  tsaEligible  waterLevel
# 0         False         True           9
# 1         False         True           5
# 2         False         True          19
# 3         False         True          23
# 4          True         True          12
# 5          True         True          18
# 6         False         True          10
# 7         False         True           7
# 8         False         True          12
# 9         False         True          18
# 10        False         True           5
# 11        False         True          13
# 12        False         True          33
# 13        False         True           6
# 14        False         True          24
# 15        False         True          16
# 16        False         True           6
# 17         True         True          10
# 18        False        False          12
# 19        False         True          24
# 20        False         True          10
# 21         True         True           3
# 22        False         True          24
# 23         True         True          26
# 24        False         True          17
# 25        False        False           2
#
# [26 rows x 41 columns]

# %%
export_csv = data_df.to_csv ("IAHRLD_4332_harvey_SUGARLAND_25000.csv", encoding='utf-8', index=False, header=True)
