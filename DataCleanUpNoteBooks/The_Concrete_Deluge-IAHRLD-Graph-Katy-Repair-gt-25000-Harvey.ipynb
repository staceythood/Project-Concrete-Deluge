# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# REFERENCE LINK FOR COLUMN DEFINITION
# https://www.fema.gov/openfema-dataset-individual-assistance-housing-registrants-large-disasters-v1

# FEMA Data | KATY | Repair Amount > 25000 | 261 rows
url = "https://www.fema.gov/api/open/v1/IndividualAssistanceHousingRegistrantsLargeDisasters?$filter=damagedStateAbbreviation%20eq%20%27TX%27%20and%20damagedCity%20eq%20%27KATY%27%20and%20repairAmount%20gt%2025000"

# Request articles
articles = requests.get(url).json()

print("FEMA DataSet : Individual Assistance Housing Registrants Large Disasters | KATY | Repair Amount > 25000")

data_df = pd.DataFrame(articles["IndividualAssistanceHousingRegistrantsLargeDisasters"])
data_df
# Out:
# FEMA DataSet : Individual Assistance Housing Registrants Large Disasters | KATY | Repair Amount > 25000
#        censusBlockId censusYear damagedCity damagedStateAbbreviation  \
# 0    481576731012054       2017        KATY                       TX
# 1    481576730022043       2017        KATY                       TX
# 2    481576730022031       2017        KATY                       TX
# 3    481576730021050       2017        KATY                       TX
# 4    481576730022034       2017        KATY                       TX
# 5    481576730021013       2017        KATY                       TX
# 6    481576730021019       2017        KATY                       TX
# 7    481576730022031       2017        KATY                       TX
# 8    481576730022031       2017        KATY                       TX
# 9    481576730021013       2017        KATY                       TX
# 10   481576730022008       2017        KATY                       TX
# ...

# %%
export_csv = data_df.to_csv ("IAHRLD_4332_harvey_KATY_25000.csv", encoding='utf-8', index=False, header=True)

# %%
data_df['rpfvl'].sum()
# Out:
# 7679359.119999999
