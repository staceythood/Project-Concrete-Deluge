# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# REFERENCE LINK FOR COLUMN DEFINITION
# https://www.fema.gov/openfema-dataset-individual-assistance-housing-registrants-large-disasters-v1

# FEMA Data | SPRING | Repair Amount > 25000 | 219 rows
url = "https://www.fema.gov/api/open/v1/IndividualAssistanceHousingRegistrantsLargeDisasters?$filter=damagedStateAbbreviation%20eq%20%27TX%27%20and%20damagedCity%20eq%20%27SPRING%27%20and%20repairAmount%20gt%2025000"

# Request articles
articles = requests.get(url).json()

print("FEMA DataSet : Individual Assistance Housing Registrants Large Disasters | SPRING | Repair Amount > 25000")

data_df = pd.DataFrame(articles["IndividualAssistanceHousingRegistrantsLargeDisasters"])
data_df
# Out:
# FEMA DataSet : Individual Assistance Housing Registrants Large Disasters | SPRING | Repair Amount > 25000
#        censusBlockId censusYear damagedCity damagedStateAbbreviation  \
# 0    482015534011026       2017      SPRING                       TX
# 1    482012410001015       2017      SPRING                       TX
# 2    482015537002040       2017      SPRING                       TX
# 3    483396914001024       2017      SPRING                       TX
# 4    482015536002012       2017      SPRING                       TX
# 5    482015540012017       2017      SPRING                       TX
# 6    483396919002016       2017      SPRING                       TX
# 7    483396914002013       2017      SPRING                       TX
# 8    482012413001029       2017      SPRING                       TX
# 9    482015537002028       2017      SPRING                       TX
# 10   482012410001001       2017      SPRING                       TX
# ...

# %%
export_csv = data_df.to_csv ("IAHRLD_4332_harvey_SPRING_25000.csv", encoding='utf-8', index=False, header=True)

# %%
data_df['rpfvl'].sum()
# Out:
# 7261447.149999999
