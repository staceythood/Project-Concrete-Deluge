# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# REFERENCE LINK FOR COLUMN DEFINITION
# https://www.fema.gov/openfema-dataset-individual-assistance-housing-registrants-large-disasters-v1

# FEMA Data | FRIENDSWOOD Repair Amount > 25000 | 127 rows
url = "https://www.fema.gov/api/open/v1/IndividualAssistanceHousingRegistrantsLargeDisasters?$filter=damagedStateAbbreviation%20eq%20%27TX%27%20and%20damagedCity%20eq%20%27FRIENDSWOOD%27%20and%20repairAmount%20gt%2025000"

# Request articles
articles = requests.get(url).json()

print("FEMA DataSet : Individual Assistance Housing Registrants Large Disasters | FRIENDSWOOD | Repair Amount > 25000")

data_df = pd.DataFrame(articles["IndividualAssistanceHousingRegistrantsLargeDisasters"])
data_df
# Out:
# FEMA DataSet : Individual Assistance Housing Registrants Large Disasters | FRIENDSWOOD | Repair Amount > 25000
#        censusBlockId censusYear  damagedCity damagedStateAbbreviation  \
# 0    482013508013007       2017  FRIENDSWOOD                       TX
# 1    482013508013009       2017  FRIENDSWOOD                       TX
# 2    482013508013004       2017  FRIENDSWOOD                       TX
# 3    482013508013002       2017  FRIENDSWOOD                       TX
# 4    482013508021098       2017  FRIENDSWOOD                       TX
# 5    482013508021092       2017  FRIENDSWOOD                       TX
# 6    482013508013010       2017  FRIENDSWOOD                       TX
# 7    482013508021092       2017  FRIENDSWOOD                       TX
# 8    482013508013008       2017  FRIENDSWOOD                       TX
# 9    482013508021106       2017  FRIENDSWOOD                       TX
# 10   481677202001002       2017  FRIENDSWOOD                       TX
# ...

# %%
export_csv = data_df.to_csv ("IAHRLD_4332_harvey_FRIENDSWOOD_25000.csv", encoding='utf-8', index=False, header=True)

# %%
data_df.groupby['rpfvl'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-367cd38f95d7> in <module>()
# ----> 1 data_df.groupby['rpfvl'].sum()
#
# TypeError: 'method' object is not subscriptable

# %%
data_df['rpfvl'].sum()
# Out:
# 4014224.88
