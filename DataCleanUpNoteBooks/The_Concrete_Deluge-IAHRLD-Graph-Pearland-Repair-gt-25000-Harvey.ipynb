# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# REFERENCE LINK FOR COLUMN DEFINITION
# https://www.fema.gov/openfema-dataset-individual-assistance-housing-registrants-large-disasters-v1

# FEMA Data | PEARLAND Repair Amount > 25000 | 32 rows
url = "https://www.fema.gov/api/open/v1/IndividualAssistanceHousingRegistrantsLargeDisasters?$filter=damagedStateAbbreviation%20eq%20%27TX%27%20and%20damagedCity%20eq%20%27PEARLAND%27%20and%20repairAmount%20gt%2025000"

# Request articles
articles = requests.get(url).json()

print("FEMA DataSet : Individual Assistance Housing Registrants Large Disasters | PEARLAND | Repair Amount > 25000")

data_df = pd.DataFrame(articles["IndividualAssistanceHousingRegistrantsLargeDisasters"])
data_df
# Out:
# FEMA DataSet : Individual Assistance Housing Registrants Large Disasters | PEARLAND | Repair Amount > 25000
#       censusBlockId censusYear damagedCity damagedStateAbbreviation  \
# 0   480396605006006       2017    PEARLAND                       TX
# 1   480396605002070       2017    PEARLAND                       TX
# 2   480396604003015       2017    PEARLAND                       TX
# 3   480396609004015       2017    PEARLAND                       TX
# 4   480396605002054       2017    PEARLAND                       TX
# 5   480396605002069       2017    PEARLAND                       TX
# 6   480396604003017       2017    PEARLAND                       TX
# 7   480396601001000       2017    PEARLAND                       TX
# 8   480396605001000       2017    PEARLAND                       TX
# 9   480396605002061       2017    PEARLAND                       TX
# 10  480396608013005       2017    PEARLAND                       TX
# ...

# %%
export_csv = data_df.to_csv ("IAHRLD_4332_harvey_PEARLAND_25000.csv", encoding='utf-8', index=False, header=True)

# %%
data_df['rpfvl'].sum()
# Out:
# 901241.6499999999
