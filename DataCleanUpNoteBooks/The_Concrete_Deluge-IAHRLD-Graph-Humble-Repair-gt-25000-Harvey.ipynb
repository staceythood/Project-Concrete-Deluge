# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# REFERENCE LINK FOR COLUMN DEFINITION
# https://www.fema.gov/openfema-dataset-individual-assistance-housing-registrants-large-disasters-v1

# FEMA Data | HUMBLE Repair Amount > 25000 | 208 rows
url = "https://www.fema.gov/api/open/v1/IndividualAssistanceHousingRegistrantsLargeDisasters?$filter=damagedStateAbbreviation%20eq%20%27TX%27%20and%20damagedCity%20eq%20%27HUMBLE%27%20and%20repairAmount%20gt%2025000"

# Request articles
articles = requests.get(url).json()

print("FEMA DataSet : Individual Assistance Housing Registrants Large Disasters | HUMBLE | Repair Amount > 25000")

data_df = pd.DataFrame(articles["IndividualAssistanceHousingRegistrantsLargeDisasters"])
data_df
# Out:
# FEMA DataSet : Individual Assistance Housing Registrants Large Disasters | HUMBLE | Repair Amount > 25000
#        censusBlockId censusYear damagedCity damagedStateAbbreviation  \
# 0    482012409021016       2017      HUMBLE                       TX
# 1    482012507012083       2017      HUMBLE                       TX
# 2    482012408021064       2017      HUMBLE                       TX
# 3    482012508003070       2017      HUMBLE                       TX
# 4    482012409021012       2017      HUMBLE                       TX
# 5    482012508002019       2017      HUMBLE                       TX
# 6    482012322004064       2017      HUMBLE                       TX
# 7    482012508003018       2017      HUMBLE                       TX
# 8    482012408021063       2017      HUMBLE                       TX
# 9    482012508003007       2017      HUMBLE                       TX
# 10   482012507012083       2017      HUMBLE                       TX
# ...

# %%
export_csv = data_df.to_csv ("IAHRLD_4332_harvey_HUMBLE_25000.csv", encoding='utf-8', index=False, header=True)

# %%
data_df['rpfvl'].sum()
# Out:
# 7245445.54
