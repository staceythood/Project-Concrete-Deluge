# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# REFERENCE LINK FOR COLUMN DEFINITION
# https://www.fema.gov/openfema-dataset-housing-assistance-data-owners-v1

# FEMA Data | Dolly Damage > 5000 | 72 rows | Some Houston Outliers
url = "https://www.fema.gov/api/open/v1/HousingAssistanceOwners?$filter=state%20eq%20%27TX%27%20and%20disasterNumber%20eq%20%271780%27%20and%20totalDamage%20gt%20%275000%27"

# Request articles
articles = requests.get(url).json()

print("FEMA DataSet : Housing Assistance Owners | Dolly Damage > 5000")

data_df = pd.DataFrame(articles["HousingAssistanceOwners"])
data_df
# Out:
# FEMA DataSet : Housing Assistance Owners | Dolly Damage > 5000
#     approvedBetween10001And25000  approvedBetween1And10000  \
# 0                              2                       192
# 1                              1                         9
# 2                              1                       106
# 3                              1                       139
# 4                             19                       525
# 5                              0                        18
# 6                              0                        16
# 7                              0                         8
# 8                              0                        18
# 9                              3                        26
# 10                             0                         2
# 11                             1                        21
# 12                            11                       276
# 13                             0                        27
# ...

# %%
export_csv = data_df.to_csv ("HousingAssistanceOwners_1780_dolly.csv", encoding='utf-8', index=False, header=True)
