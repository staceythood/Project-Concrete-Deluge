# %%
# Dependencies
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests

# REFERENCE LINK FOR COLUMN DEFINITION
# https://www.fema.gov/openfema-dataset-housing-assistance-data-owners-v1

# FEMA Data | Ike Damage > 5000 | 571 rows | Some Houston Outliers
url = "https://www.fema.gov/api/open/v1/HousingAssistanceOwners?$filter=state%20eq%20%27TX%27%20and%20disasterNumber%20eq%20%271791%27%20and%20totalDamage%20gt%20%275000%27"

# Request articles
articles = requests.get(url).json()

print("FEMA DataSet : Housing Assistance Owners | Ike Damage > 5000")

data_df = pd.DataFrame(articles["HousingAssistanceOwners"])
data_df
# Out:
# FEMA DataSet : Housing Assistance Owners | Ike Damage > 5000
#      approvedBetween10001And25000  approvedBetween1And10000  \
# 0                               0                         0
# 1                               1                        57
# 2                               0                         0
# 3                               1                         1
# 4                               3                       213
# 5                               1                         5
# 6                               8                       152
# 7                               0                         2
# 8                               0                        12
# 9                               4                        82
# 10                              0                        28
# 11                              1                       204
# 12                              0                         3
# 13                             18                       266
# ...

# %%
export_csv = data_df.to_csv ("HousingAssistanceOwners_1791_ike.csv", encoding='utf-8', index=False, header=True)
